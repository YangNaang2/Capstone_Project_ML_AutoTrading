# %%
# !pip install backtrader
# !pip install yfinance
# Out:
# Requirement already satisfied: backtrader in /usr/local/lib/python3.10/dist-packages (1.9.78.123)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.50)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.12.14)

# %%
import backtrader as bt
import math
import yfinance as yf

# %% [markdown]
# 추세전략

# %%
class BollingerBands(bt.Strategy):
  params = dict(
      bb_period=20, # 볼린저 밴드 기간
      bb_devfactor=1, # 볼린저 밴드 표준편차
      ma_period=50 # 이동평균선 기간
  )

  def __init__(self):
    # 볼린저밴드
    self.bb = bt.indicators.BollingerBands(self.data.close, period=self.params.bb_period, devfactor=self.params.bb_devfactor)
    # 이동평균선
    self.ma = bt.indicators.MovingAverageSimple(self.data.close, period=self.params.ma_period)
    # 매수 신호 추적 변수
    self.order = None

  def next(self):
    if self.order:  # 만약 주문이 있으면 대기
      return
    # 포지션이 없을 때(시장 미진입 상태)
    if not self.position:
      # 매수 : 종가가 볼린저 밴드 상단선을 돌파
      if self.data.close[0] > self.bb.lines.top[0]:
        order_size = math.floor(self.broker.get_value() / self.datas[0].close * 0.99)
        self.buy(size=order_size)

    # 포지션이 있을 때(시장 진입 상태)
    else:
      # 종가가 이평선 하향 돌파 -> 청산
      if self.data.close[0] < self.ma[0]:
        self.close()


  def log(self, message):
    print(message)

  def notify_order(self, order):
    if order.status in [order.Submitted, order.Accepted]:
      # Buy/Sell order submitted/accepted to/by broker - Nothing to do
      return

    # Check if an order has been completed
    # Attention: broker could reject order if not enough cash
    cur_date = None
    if order.status in [order.Completed]:
      cur_date = order.data.datetime.date(0)
      if order.isbuy():
        self.log(
            f'{cur_date} [매수 주문 실행] 종목: {order.data._name} \t 수량: {order.size} \t 가격: {order.executed.price:.2f}')
      elif order.issell():
        self.log(
            f'{cur_date} [매도 주문 실행] 종목: {order.data._name} \t 수량: {order.size} \t 가격: {order.executed.price:.2f}')
      self.bar_executed = len(self)

    elif order.status in [order.Canceled, order.Margin, order.Rejected]:
      self.log(
          f'{cur_date} 주문이 거부되었습니다. 종목: {order.data._name} \t 수량: {order.size} \t 가격: {order.executed.price:.2f}')

# %%
if __name__ == '__main__':

  cerebro = bt.Cerebro()
  cerebro.addstrategy(BollingerBands)
  cerebro.broker.setcommission(commission=0.003) # 수수료 0.3%
  cerebro.broker.setcash(10_000_000)

  print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
  data = yf.download('BTC-USD', start='2020-01-01', end='2024-12-01')
  # 열 이름 전처리
  data.columns = [col[0] if isinstance(col, tuple) else col for col in data.columns]
  data_bt = bt.feeds.PandasData(dataname=data)
  cerebro.adddata(data_bt)
  cerebro.run()
  print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
  print(f'수익률: {cerebro.broker.getvalue() / 10_000_000 * 100:.2f}%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Starting Portfolio Value: 10000000.00
# 2020-04-02 [매수 주문 실행] 종목:  	 수량: 1498 	 가격: 6606.78
# 2020-04-03 [매도 주문 실행] 종목:  	 수량: -1498 	 가격: 6797.40
# 2020-04-04 [매수 주문 실행] 종목:  	 수량: 1503 	 가격: 6738.38
# 2020-04-05 [매도 주문 실행] 종목:  	 수량: -1503 	 가격: 6862.54
# 2020-04-07 [매수 주문 실행] 종목:  	 수량: 1409 	 가격: 7273.64
# 2020-04-08 [매도 주문 실행] 종목:  	 수량: -1409 	 가격: 7179.28
# 2020-04-09 [매수 주문 실행] 종목:  	 수량: 1370 	 가격: 7337.97
# 2020-04-10 [매도 주문 실행] 종목:  	 수량: -1370 	 가격: 7303.82
# 2020-04-19 [매수 주문 실행] 종목:  	 수량: 1370 	 가격: 7260.92
# 2020-06-20 [매도 주문 실행] 종목:  	 수량: -1370 	 가격: 9290.96
# 2020-07-09 [매수 주문 실행] 종목:  	 수량: 1340 	 가격: 9427.99
# 2020-07-10 [매도 주문 실행] 종목:  	 수량: -1340 	 가격: 9273.36
# 2020-07-22 [매수 주문 실행] 종목:  	 수량: 1317 	 가격: 9375.08
# 2020-09-04 [매도 주문 실행] 종목:  	 수량: -1317 	 가격: 10230.37
# 2020-10-09 [매수 주문 실행] 종목:  	 수량: 1227 	 가격: 10927.91
# 2021-04-19 [매도 주문 실행] 종목:  	 수량: -1227 	 가격: 56191.59
# 2021-05-09 [매수 주문 실행] 종목:  	 수량: 1158 	 가격: 58877.39
# 2021-05-11 [매도 주문 실행] 종목:  	 수량: -1158 	 가격: 55847.24
# 2021-06-14 [매수 주문 실행] 종목:  	 수량: 1643 	 가격: 39016.97
# 2021-06-15 [매도 주문 실행] 종목:  	 수량: -1643 	 가격: 40427.17
# 2021-06-16 [매수 주문 실행] 종목:  	 수량: 1637 	 가격: 40168.69
# 2021-06-17 [매도 주문 실행] 종목:  	 수량: -1637 	 가격: 38341.42
# 2021-07-25 [매수 주문 실행] 종목:  	 수량: 1832 	 가격: 34290.29
# 2021-09-11 [매도 주문 실행] 종목:  	 수량: -1832 	 가격: 44869.84
# 2021-10-02 [매수 주문 실행] 종목:  	 수량: 1695 	 가격: 48137.47
# 2021-11-19 [매도 주문 실행] 종목:  	 수량: -1695 	 가격: 56896.13
# 2021-12-24 [매수 주문 실행] 종목:  	 수량: 1885 	 가격: 50806.05
# 2021-12-25 [매도 주문 실행] 종목:  	 수량: -1885 	 가격: 50854.92
# 2021-12-26 [매수 주문 실행] 종목:  	 수량: 1889 	 가격: 50428.69
# 2021-12-27 [매도 주문 실행] 종목:  	 수량: -1889 	 가격: 50802.61
# 2021-12-28 [매수 주문 실행] 종목:  	 수량: 1883 	 가격: 50679.86
# 2021-12-29 [매도 주문 실행] 종목:  	 수량: -1883 	 가격: 47623.87
# 2022-02-05 [매수 주문 실행] 종목:  	 수량: 2148 	 가격: 41501.48
# 2022-02-06 [매도 주문 실행] 종목:  	 수량: -2148 	 가격: 41441.12
# 2022-02-07 [매수 주문 실행] 종목:  	 수량: 2086 	 가격: 42406.78
# 2022-02-12 [매도 주문 실행] 종목:  	 수량: -2086 	 가격: 42412.30
# 2022-02-16 [매수 주문 실행] 종목:  	 수량: 1973 	 가격: 44578.28
# 2022-02-18 [매도 주문 실행] 종목:  	 수량: -1973 	 가격: 40552.13
# 2022-03-02 [매수 주문 실행] 종목:  	 수량: 1795 	 가격: 44357.62
# 2022-03-05 [매도 주문 실행] 종목:  	 수량: -1795 	 가격: 39148.45
# 2022-03-10 [매수 주문 실행] 종목:  	 수량: 1665 	 가격: 41974.07
# 2022-03-11 [매도 주문 실행] 종목:  	 수량: -1665 	 가격: 39439.97
# 2022-03-23 [매수 주문 실행] 종목:  	 수량: 1542 	 가격: 42364.38
# 2022-04-12 [매도 주문 실행] 종목:  	 수량: -1542 	 가격: 39533.71
# 2022-05-31 [매수 주문 실행] 종목:  	 수량: 1911 	 가격: 31723.87
# 2022-06-01 [매도 주문 실행] 종목:  	 수량: -1911 	 가격: 31792.55
# 2022-06-07 [매수 주문 실행] 종목:  	 수량: 1925 	 가격: 31371.74
# 2022-06-08 [매도 주문 실행] 종목:  	 수량: -1925 	 가격: 31151.48
# 2022-07-08 [매수 주문 실행] 종목:  	 수량: 2756 	 가격: 21637.15
# 2022-07-09 [매도 주문 실행] 종목:  	 수량: -2756 	 가격: 21716.83
# 2022-07-10 [매수 주문 실행] 종목:  	 수량: 2755 	 가격: 21591.08
# 2022-07-11 [매도 주문 실행] 종목:  	 수량: -2755 	 가격: 20856.35
# 2022-07-17 [매수 주문 실행] 종목:  	 수량: 2697 	 가격: 21195.04
# 2022-07-18 [매도 주문 실행] 종목:  	 수량: -2697 	 가격: 20781.91
# 2022-07-19 [매수 주문 실행] 종목:  	 수량: 2477 	 가격: 22467.85
# 2022-07-24 [매도 주문 실행] 종목:  	 수량: -2477 	 가격: 22465.51
# 2022-07-28 [매수 주문 실행] 종목:  	 수량: 2414 	 가격: 22933.64
# 2022-08-20 [매도 주문 실행] 종목:  	 수량: -2414 	 가격: 20872.84
# 2022-09-10 [매수 주문 실행] 종목:  	 수량: 2344 	 가격: 21376.91
# 2022-09-11 [매도 주문 실행] 종목:  	 수량: -2344 	 가격: 21678.54
# 2022-09-12 [매수 주문 실행] 종목:  	 수량: 2321 	 가격: 21770.15
# 2022-09-14 [매도 주문 실행] 종목:  	 수량: -2321 	 가격: 20184.55
# 2022-10-05 [매수 주문 실행] 종목:  	 수량: 2291 	 가격: 20335.90
# 2022-10-06 [매도 주문 실행] 종목:  	 수량: -2291 	 가격: 20161.04
# 2022-10-07 [매수 주문 실행] 종목:  	 수량: 2301 	 가격: 19957.56
# 2022-10-08 [매도 주문 실행] 종목:  	 수량: -2301 	 가격: 19546.33
# 2022-10-26 [매수 주문 실행] 종목:  	 수량: 2225 	 가격: 20092.24
# 2022-11-09 [매도 주문 실행] 종목:  	 수량: -2225 	 가격: 18543.76
# 2022-12-01 [매수 주문 실행] 종목:  	 수량: 2391 	 가격: 17168.00
# 2022-12-02 [매도 주문 실행] 종목:  	 수량: -2391 	 가격: 16968.68
# 2022-12-03 [매수 주문 실행] 종목:  	 수량: 2360 	 가격: 17090.10
# 2022-12-04 [매도 주문 실행] 종목:  	 수량: -2360 	 가격: 16908.17
# 2022-12-05 [매수 주문 실행] 종목:  	 수량: 2316 	 가격: 17128.89
# 2022-12-06 [매도 주문 실행] 종목:  	 수량: -2316 	 가격: 16975.24
# 2022-12-07 [매수 주문 실행] 종목:  	 수량: 2287 	 가격: 17089.51
# 2022-12-08 [매도 주문 실행] 종목:  	 수량: -2287 	 가격: 16847.35
# 2022-12-09 [매수 주문 실행] 종목:  	 수량: 2223 	 가격: 17232.15
# 2022-12-10 [매도 주문 실행] 종목:  	 수량: -2223 	 가격: 17134.22
# 2022-12-13 [매수 주문 실행] 종목:  	 수량: 2201 	 가격: 17206.44
# 2022-12-14 [매도 주문 실행] 종목:  	 수량: -2201 	 가격: 17782.07
# 2022-12-15 [매수 주문 실행] 종목:  	 수량: 2183 	 가격: 17813.64
# 2022-12-16 [매도 주문 실행] 종목:  	 수량: -2183 	 가격: 17364.55
# 2023-01-05 [매수 주문 실행] 종목:  	 수량: 2235 	 가격: 16863.47
# 2023-03-04 [매도 주문 실행] 종목:  	 수량: -2235 	 가격: 22362.92
# 2023-03-14 [매수 주문 실행] 종목:  	 수량: 2050 	 가격: 24201.77
# 2023-05-02 [매도 주문 실행] 종목:  	 수량: -2050 	 가격: 28087.18
# 2023-05-29 [매수 주문 실행] 종목:  	 수량: 2035 	 가격: 28075.59
# 2023-05-30 [매도 주문 실행] 종목:  	 수량: -2035 	 가격: 27745.12
# 2023-05-31 [매수 주문 실행] 종목:  	 수량: 2027 	 가격: 27700.53
# 2023-06-01 [매도 주문 실행] 종목:  	 수량: -2027 	 가격: 27218.41
# 2023-06-21 [매수 주문 실행] 종목:  	 수량: 1937 	 가격: 28311.31
# 2023-07-31 [매도 주문 실행] 종목:  	 수량: -1937 	 가격: 29278.31
# 2023-08-09 [매수 주문 실행] 종목:  	 수량: 1894 	 가격: 29766.70
# 2023-08-10 [매도 주문 실행] 종목:  	 수량: -1894 	 가격: 29563.97
# 2023-09-19 [매수 주문 실행] 종목:  	 수량: 2081 	 가격: 26760.85
# 2023-09-21 [매도 주문 실행] 종목:  	 수량: -2081 	 가격: 27129.84
# 2023-09-29 [매수 주문 실행] 종목:  	 수량: 2076 	 가격: 27024.84
# 2024-01-15 [매도 주문 실행] 종목:  	 수량: -2076 	 가격: 41715.07
# 2024-02-02 [매수 주문 실행] 종목:  	 수량: 1993 	 가격: 43077.64
# 2024-02-05 [매도 주문 실행] 종목:  	 수량: -1993 	 가격: 42577.62
# 2024-02-07 [매수 주문 실행] 종목:  	 수량: 1958 	 가격: 43090.02
# 2024-04-14 [매도 주문 실행] 종목:  	 수량: -1958 	 가격: 63836.23
# 2024-05-16 [매수 주문 실행] 종목:  	 수량: 1870 	 가격: 66256.11
# 2024-06-15 [매도 주문 실행] 종목:  	 수량: -1870 	 가격: 66006.74
# 2024-07-16 [매수 주문 실행] 종목:  	 수량: 1892 	 가격: 64784.42
# 2024-08-03 [매도 주문 실행] 종목:  	 수량: -1892 	 가격: 61414.81
# 2024-08-22 [매수 주문 실행] 종목:  	 수량: 1892 	 가격: 61168.32
# 2024-08-23 [매도 주문 실행] 종목:  	 수량: -1892 	 가격: 60380.95
# 2024-08-24 [매수 주문 실행] 종목:  	 수량: 1772 	 가격: 64103.87
# 2024-08-28 [매도 주문 실행] 종목:  	 수량: -1772 	 가격: 59507.93
# 2024-09-18 [매수 주문 실행] 종목:  	 수량: 1739 	 가격: 60309.00
# 2024-10-10 [매도 주문 실행] 종목:  	 수량: -1739 	 가격: 60581.93
# 2024-10-15 [매수 주문 실행] 종목:  	 수량: 1585 	 가격: 66050.37
# Final Portfolio Value: 153660816.56
# 수익률: 1536.61%

# %% [markdown]
# 스탑로스 10% 설정

# %%
class BollingerBandsStopLoss(bt.Strategy):
  params = dict(
      bb_period=20, # 볼린저 밴드 기간
      bb_devfactor=1, # 볼린저 밴드 표준편차
      ma_period=50, # 이동평균선 기간
      stop_loss=0.1, # 손절 비율(10%)
  )

  def __init__(self):
    # 볼린저밴드
    self.bb = bt.indicators.BollingerBands(self.data.close, period=self.params.bb_period, devfactor=self.params.bb_devfactor)
    # 이동평균선
    self.ma = bt.indicators.MovingAverageSimple(self.data.close, period=self.params.ma_period)
    # 매수 신호 추적 변수
    self.order = None
    # 매수 가격 저장
    self.buy_price = None

  def next(self):
    if self.order:  # 만약 주문이 있으면 대기
      return
    # 포지션이 없을 때(시장 미진입 상태)
    if not self.position:
      # 매수 : 종가가 볼린저 밴드 상단선을 돌파
      if self.data.close[0] > self.bb.lines.top[0]:
        order_size = math.floor(self.broker.get_value() / self.datas[0].close * 0.99)
        self.buy(size=order_size)
        self.buy_price = self.data.close[0]

    # 포지션이 있을 때(시장 진입 상태)
    else:
      # 종가가 이평선 하향 돌파 or 매수가 대비 10% 하락 -> 청산
      stop_loss_price = self.buy_price * (1 - self.params.stop_loss) # 손절가 계산
      if self.data.close[0] < stop_loss_price or self.data.close[0] < self.ma[0]:
        self.close()
        self.buy_price = None # 매도 후 매수 가격 초기화


  def log(self, message):
    print(message)

  def notify_order(self, order):
    if order.status in [order.Submitted, order.Accepted]:
      # Buy/Sell order submitted/accepted to/by broker - Nothing to do
      return

    # Check if an order has been completed
    # Attention: broker could reject order if not enough cash
    cur_date = None
    if order.status in [order.Completed]:
      cur_date = order.data.datetime.date(0)
      if order.isbuy():
        self.log(
            f'{cur_date} [매수 주문 실행] 종목: {order.data._name} \t 수량: {order.size} \t 가격: {order.executed.price:.2f}')
      elif order.issell():
        self.log(
            f'{cur_date} [매도 주문 실행] 종목: {order.data._name} \t 수량: {order.size} \t 가격: {order.executed.price:.2f}')
      self.bar_executed = len(self)

    elif order.status in [order.Canceled, order.Margin, order.Rejected]:
      self.log(
          f'{cur_date} 주문이 거부되었습니다. 종목: {order.data._name} \t 수량: {order.size} \t 가격: {order.executed.price:.2f}')

# %%
if __name__ == '__main__':

  cerebro = bt.Cerebro()
  cerebro.addstrategy(BollingerBandsStopLoss)
  cerebro.broker.setcommission(commission=0.003) # 수수료 0.3%
  cerebro.broker.setcash(10_000_000)

  print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
  data = yf.download('BTC-USD', start='2020-01-01', end='2024-12-01')
  # 열 이름 전처리
  data.columns = [col[0] if isinstance(col, tuple) else col for col in data.columns]
  data_bt = bt.feeds.PandasData(dataname=data)
  cerebro.adddata(data_bt)
  cerebro.run()
  print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
  print(f'수익률: {cerebro.broker.getvalue() / 10_000_000 * 100:.2f}%')
# Out:
# Starting Portfolio Value: 10000000.00
# [*********************100%***********************]  1 of 1 completed
# 2020-04-02 [매수 주문 실행] 종목:  	 수량: 1498 	 가격: 6606.78
# 2020-04-03 [매도 주문 실행] 종목:  	 수량: -1498 	 가격: 6797.40
# 2020-04-04 [매수 주문 실행] 종목:  	 수량: 1503 	 가격: 6738.38
# 2020-04-05 [매도 주문 실행] 종목:  	 수량: -1503 	 가격: 6862.54
# 2020-04-07 [매수 주문 실행] 종목:  	 수량: 1409 	 가격: 7273.64
# 2020-04-08 [매도 주문 실행] 종목:  	 수량: -1409 	 가격: 7179.28
# 2020-04-09 [매수 주문 실행] 종목:  	 수량: 1370 	 가격: 7337.97
# 2020-04-10 [매도 주문 실행] 종목:  	 수량: -1370 	 가격: 7303.82
# 2020-04-19 [매수 주문 실행] 종목:  	 수량: 1370 	 가격: 7260.92
# 2020-06-20 [매도 주문 실행] 종목:  	 수량: -1370 	 가격: 9290.96
# 2020-07-09 [매수 주문 실행] 종목:  	 수량: 1340 	 가격: 9427.99
# 2020-07-10 [매도 주문 실행] 종목:  	 수량: -1340 	 가격: 9273.36
# 2020-07-22 [매수 주문 실행] 종목:  	 수량: 1317 	 가격: 9375.08
# 2020-09-04 [매도 주문 실행] 종목:  	 수량: -1317 	 가격: 10230.37
# 2020-10-09 [매수 주문 실행] 종목:  	 수량: 1227 	 가격: 10927.91
# 2021-04-19 [매도 주문 실행] 종목:  	 수량: -1227 	 가격: 56191.59
# 2021-05-09 [매수 주문 실행] 종목:  	 수량: 1158 	 가격: 58877.39
# 2021-05-11 [매도 주문 실행] 종목:  	 수량: -1158 	 가격: 55847.24
# 2021-06-14 [매수 주문 실행] 종목:  	 수량: 1643 	 가격: 39016.97
# 2021-06-15 [매도 주문 실행] 종목:  	 수량: -1643 	 가격: 40427.17
# 2021-06-16 [매수 주문 실행] 종목:  	 수량: 1637 	 가격: 40168.69
# 2021-06-17 [매도 주문 실행] 종목:  	 수량: -1637 	 가격: 38341.42
# 2021-07-25 [매수 주문 실행] 종목:  	 수량: 1832 	 가격: 34290.29
# 2021-09-11 [매도 주문 실행] 종목:  	 수량: -1832 	 가격: 44869.84
# 2021-10-02 [매수 주문 실행] 종목:  	 수량: 1695 	 가격: 48137.47
# 2021-11-19 [매도 주문 실행] 종목:  	 수량: -1695 	 가격: 56896.13
# 2021-12-24 [매수 주문 실행] 종목:  	 수량: 1885 	 가격: 50806.05
# 2021-12-25 [매도 주문 실행] 종목:  	 수량: -1885 	 가격: 50854.92
# 2021-12-26 [매수 주문 실행] 종목:  	 수량: 1889 	 가격: 50428.69
# 2021-12-27 [매도 주문 실행] 종목:  	 수량: -1889 	 가격: 50802.61
# 2021-12-28 [매수 주문 실행] 종목:  	 수량: 1883 	 가격: 50679.86
# 2021-12-29 [매도 주문 실행] 종목:  	 수량: -1883 	 가격: 47623.87
# 2022-02-05 [매수 주문 실행] 종목:  	 수량: 2148 	 가격: 41501.48
# 2022-02-06 [매도 주문 실행] 종목:  	 수량: -2148 	 가격: 41441.12
# 2022-02-07 [매수 주문 실행] 종목:  	 수량: 2086 	 가격: 42406.78
# 2022-02-12 [매도 주문 실행] 종목:  	 수량: -2086 	 가격: 42412.30
# 2022-02-16 [매수 주문 실행] 종목:  	 수량: 1973 	 가격: 44578.28
# 2022-02-18 [매도 주문 실행] 종목:  	 수량: -1973 	 가격: 40552.13
# 2022-03-02 [매수 주문 실행] 종목:  	 수량: 1795 	 가격: 44357.62
# 2022-03-05 [매도 주문 실행] 종목:  	 수량: -1795 	 가격: 39148.45
# 2022-03-10 [매수 주문 실행] 종목:  	 수량: 1665 	 가격: 41974.07
# 2022-03-11 [매도 주문 실행] 종목:  	 수량: -1665 	 가격: 39439.97
# 2022-03-23 [매수 주문 실행] 종목:  	 수량: 1542 	 가격: 42364.38
# 2022-04-12 [매도 주문 실행] 종목:  	 수량: -1542 	 가격: 39533.71
# 2022-05-31 [매수 주문 실행] 종목:  	 수량: 1911 	 가격: 31723.87
# 2022-06-01 [매도 주문 실행] 종목:  	 수량: -1911 	 가격: 31792.55
# 2022-06-07 [매수 주문 실행] 종목:  	 수량: 1925 	 가격: 31371.74
# 2022-06-08 [매도 주문 실행] 종목:  	 수량: -1925 	 가격: 31151.48
# 2022-07-08 [매수 주문 실행] 종목:  	 수량: 2756 	 가격: 21637.15
# 2022-07-09 [매도 주문 실행] 종목:  	 수량: -2756 	 가격: 21716.83
# 2022-07-10 [매수 주문 실행] 종목:  	 수량: 2755 	 가격: 21591.08
# 2022-07-11 [매도 주문 실행] 종목:  	 수량: -2755 	 가격: 20856.35
# 2022-07-17 [매수 주문 실행] 종목:  	 수량: 2697 	 가격: 21195.04
# 2022-07-18 [매도 주문 실행] 종목:  	 수량: -2697 	 가격: 20781.91
# 2022-07-19 [매수 주문 실행] 종목:  	 수량: 2477 	 가격: 22467.85
# 2022-07-24 [매도 주문 실행] 종목:  	 수량: -2477 	 가격: 22465.51
# 2022-07-28 [매수 주문 실행] 종목:  	 수량: 2414 	 가격: 22933.64
# 2022-08-20 [매도 주문 실행] 종목:  	 수량: -2414 	 가격: 20872.84
# 2022-09-10 [매수 주문 실행] 종목:  	 수량: 2344 	 가격: 21376.91
# 2022-09-11 [매도 주문 실행] 종목:  	 수량: -2344 	 가격: 21678.54
# 2022-09-12 [매수 주문 실행] 종목:  	 수량: 2321 	 가격: 21770.15
# 2022-09-14 [매도 주문 실행] 종목:  	 수량: -2321 	 가격: 20184.55
# 2022-10-05 [매수 주문 실행] 종목:  	 수량: 2291 	 가격: 20335.90
# 2022-10-06 [매도 주문 실행] 종목:  	 수량: -2291 	 가격: 20161.04
# 2022-10-07 [매수 주문 실행] 종목:  	 수량: 2301 	 가격: 19957.56
# 2022-10-08 [매도 주문 실행] 종목:  	 수량: -2301 	 가격: 19546.33
# 2022-10-26 [매수 주문 실행] 종목:  	 수량: 2225 	 가격: 20092.24
# 2022-11-09 [매도 주문 실행] 종목:  	 수량: -2225 	 가격: 18543.76
# 2022-12-01 [매수 주문 실행] 종목:  	 수량: 2391 	 가격: 17168.00
# 2022-12-02 [매도 주문 실행] 종목:  	 수량: -2391 	 가격: 16968.68
# 2022-12-03 [매수 주문 실행] 종목:  	 수량: 2360 	 가격: 17090.10
# 2022-12-04 [매도 주문 실행] 종목:  	 수량: -2360 	 가격: 16908.17
# 2022-12-05 [매수 주문 실행] 종목:  	 수량: 2316 	 가격: 17128.89
# 2022-12-06 [매도 주문 실행] 종목:  	 수량: -2316 	 가격: 16975.24
# 2022-12-07 [매수 주문 실행] 종목:  	 수량: 2287 	 가격: 17089.51
# 2022-12-08 [매도 주문 실행] 종목:  	 수량: -2287 	 가격: 16847.35
# 2022-12-09 [매수 주문 실행] 종목:  	 수량: 2223 	 가격: 17232.15
# 2022-12-10 [매도 주문 실행] 종목:  	 수량: -2223 	 가격: 17134.22
# 2022-12-13 [매수 주문 실행] 종목:  	 수량: 2201 	 가격: 17206.44
# 2022-12-14 [매도 주문 실행] 종목:  	 수량: -2201 	 가격: 17782.07
# 2022-12-15 [매수 주문 실행] 종목:  	 수량: 2183 	 가격: 17813.64
# 2022-12-16 [매도 주문 실행] 종목:  	 수량: -2183 	 가격: 17364.55
# 2023-01-05 [매수 주문 실행] 종목:  	 수량: 2235 	 가격: 16863.47
# 2023-03-04 [매도 주문 실행] 종목:  	 수량: -2235 	 가격: 22362.92
# 2023-03-14 [매수 주문 실행] 종목:  	 수량: 2050 	 가격: 24201.77
# 2023-05-02 [매도 주문 실행] 종목:  	 수량: -2050 	 가격: 28087.18
# 2023-05-29 [매수 주문 실행] 종목:  	 수량: 2035 	 가격: 28075.59
# 2023-05-30 [매도 주문 실행] 종목:  	 수량: -2035 	 가격: 27745.12
# 2023-05-31 [매수 주문 실행] 종목:  	 수량: 2027 	 가격: 27700.53
# 2023-06-01 [매도 주문 실행] 종목:  	 수량: -2027 	 가격: 27218.41
# 2023-06-21 [매수 주문 실행] 종목:  	 수량: 1937 	 가격: 28311.31
# 2023-07-31 [매도 주문 실행] 종목:  	 수량: -1937 	 가격: 29278.31
# 2023-08-09 [매수 주문 실행] 종목:  	 수량: 1894 	 가격: 29766.70
# 2023-08-10 [매도 주문 실행] 종목:  	 수량: -1894 	 가격: 29563.97
# 2023-09-19 [매수 주문 실행] 종목:  	 수량: 2081 	 가격: 26760.85
# 2023-09-21 [매도 주문 실행] 종목:  	 수량: -2081 	 가격: 27129.84
# 2023-09-29 [매수 주문 실행] 종목:  	 수량: 2076 	 가격: 27024.84
# 2024-01-15 [매도 주문 실행] 종목:  	 수량: -2076 	 가격: 41715.07
# 2024-02-02 [매수 주문 실행] 종목:  	 수량: 1993 	 가격: 43077.64
# 2024-02-05 [매도 주문 실행] 종목:  	 수량: -1993 	 가격: 42577.62
# 2024-02-07 [매수 주문 실행] 종목:  	 수량: 1958 	 가격: 43090.02
# 2024-04-14 [매도 주문 실행] 종목:  	 수량: -1958 	 가격: 63836.23
# 2024-05-16 [매수 주문 실행] 종목:  	 수량: 1870 	 가격: 66256.11
# 2024-06-15 [매도 주문 실행] 종목:  	 수량: -1870 	 가격: 66006.74
# 2024-07-16 [매수 주문 실행] 종목:  	 수량: 1892 	 가격: 64784.42
# 2024-08-03 [매도 주문 실행] 종목:  	 수량: -1892 	 가격: 61414.81
# 2024-08-22 [매수 주문 실행] 종목:  	 수량: 1892 	 가격: 61168.32
# 2024-08-23 [매도 주문 실행] 종목:  	 수량: -1892 	 가격: 60380.95
# 2024-08-24 [매수 주문 실행] 종목:  	 수량: 1772 	 가격: 64103.87
# 2024-08-28 [매도 주문 실행] 종목:  	 수량: -1772 	 가격: 59507.93
# 2024-09-18 [매수 주문 실행] 종목:  	 수량: 1739 	 가격: 60309.00
# 2024-10-10 [매도 주문 실행] 종목:  	 수량: -1739 	 가격: 60581.93
# 2024-10-15 [매수 주문 실행] 종목:  	 수량: 1585 	 가격: 66050.37
# Final Portfolio Value: 153660816.56
# 수익률: 1536.61%

# %% [markdown]
# 추세전략이라 그런지 스탑로스가 있어도 맨 처음것과 동일

# %% [markdown]
# +10%마다 1/5씩 분할 매수

# %%
import backtrader as bt
import math

class BollingerBandsPartialBuy(bt.Strategy):
    params = dict(
        bb_period=20,             # 볼린저 밴드 기간
        bb_devfactor=2,           # 볼린저 밴드 표준편차
        ma_period=50,             # 이동평균선 기간
        max_additional_buys=5,    # 최대 분할 매수 횟수
        drop_trigger=0.10,        # 진입가 대비 10% 상승 시마다 추가 매수
    )

    def __init__(self):
        # 볼린저밴드
        self.bb = bt.indicators.BollingerBands(
            self.data.close,
            period=self.params.bb_period,
            devfactor=self.params.bb_devfactor
        )
        # 이동평균선 (추세 확인)
        self.ma = bt.indicators.MovingAverageSimple(
            self.data.close,
            period=self.params.ma_period
        )
        self.order = None

        self.buy_price = None             # 현재까지의 '평균 단가'
        self.num_additional_buys = 0      # 분할 매수 횟수 (최대 5회까지)

    def next(self):
        # 주문 진행 중이면 대기
        if self.order:
            return

        if not self.position:
            # 볼린저 상단 돌파 시 매수(예시)
            if self.data.close[0] > self.bb.top[0]:
                order_size = math.floor(self.broker.get_value() / self.data.close[0] * 0.2)
                self.order = self.buy(size=order_size)
                # buy_price는 notify_order에서 체결가를 받아온 뒤 설정
                self.num_additional_buys = 0

        # 포지션이 있는 경우
        else:
            # 추가 매수 로직
            if self.buy_price is not None:
                current_price = self.data.close[0]
                drop_ratio = (current_price - self.buy_price) / self.buy_price

                if drop_ratio >= self.params.drop_trigger and self.num_additional_buys < self.params.max_additional_buys:
                    add_size = math.floor(self.broker.get_value() / current_price * 0.2)
                    self.order = self.buy(size=add_size)
                    # 체결 후 notify_order에서 평균단가를 갱신
                    # 추가 매수 횟수는 체결 후에 += 1로 처리

            # 청산 조건
            if self.data.close[0] < self.ma[0]:
                self.order = self.close()
                self.buy_price = None


    def log(self, txt):
        dt = self.data.datetime.date(0)
        print(f'{dt} - {txt}')

    def notify_order(self, order):
        """
        주문 체결 이후의 평균단가 갱신 로직
        """
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status == order.Completed:
            dt = order.data.datetime.date(0)

            if order.isbuy():
                # 1) 체결 정보
                fill_price = order.executed.price   # 체결가
                fill_size = order.executed.size     # 체결 수량 (양수)
                self.log(f'[매수 체결] 가격:{fill_price:.2f}, 수량:{fill_size:.4f}')

                # 2) 기존 포지션 수량 (체결 완료 후 포지션에 반영됨)
                #    order가 체결된 직후, backtrader는 포지션을 업데이트하므로
                current_position_size = self.position.size

                # 3) 평균단가 갱신
                if self.buy_price is None:
                    # 최초 매수인 경우
                    self.buy_price = fill_price
                else:
                    # 추가 매수인 경우
                    # (참고) 새로 반영된 self.position.size = 이전 size + fill_size
                    # 우리가 알고 싶은 것은 "체결 직전 size"이므로:
                    old_position_size = current_position_size - fill_size

                    if old_position_size <= 0:
                        # 혹시 포지션이 0이었거나 음수였다가(숏 포지션이었다가)
                        # 이번에 매수로 롱 포지션이 됐다면 그냥 fill_price로 셋팅
                        self.buy_price = fill_price
                    else:
                        # 평균단가 = (기존포지션 * 기존평단 + 신규수량 * 체결가) / (총수량)
                        new_average = (
                            (old_position_size * self.buy_price) + (fill_size * fill_price)
                        ) / (old_position_size + fill_size)

                        self.buy_price = new_average

                # 추가 매수 횟수 증가
                if self.num_additional_buys < self.params.max_additional_buys:
                    # 최초 매수 시에는 num_additional_buys==0 -> 매수 체결이 "추가"는 아님
                    # 다만 첫 매수 후도 "추가 매수"로 셀 수도 있어 로직을 원하는 대로 수정
                    self.num_additional_buys += 1

            elif order.issell():
                fill_price = order.executed.price
                fill_size = order.executed.size
                self.log(f'[매도 체결] 가격:{fill_price:.2f}, 수량:{fill_size:.4f}')
                # 매도 후 포지션이 0이면 buy_price 초기화
                if self.position.size == 0:
                    self.buy_price = None
                    self.num_additional_buys = 0

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소/마진/거부')

        self.order = None

    def notify_trade(self, trade):
        """
        거래가 완전히 종료될 때(포지션=0) PnL 로그를 확인하고 싶다면 추가
        """
        if trade.isclosed:
            self.log(f'거래 종료 - 손익: {trade.pnl:.2f}, 수수료포함: {trade.pnlcomm:.2f}')

# %%
if __name__ == '__main__':

  cerebro = bt.Cerebro()
  cerebro.addstrategy(BollingerBandsPartialBuy)
  cerebro.broker.setcommission(commission=0.003) # 수수료 0.3%
  cerebro.broker.setcash(10_000_000)

  print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
  data = yf.download('BTC-USD', start='2020-01-01', end='2024-12-01')
  # 열 이름 전처리
  data.columns = [col[0] if isinstance(col, tuple) else col for col in data.columns]
  data_bt = bt.feeds.PandasData(dataname=data)
  cerebro.adddata(data_bt)
  cerebro.run()
  print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
  print(f'수익률: {cerebro.broker.getvalue() / 10_000_000 * 100:.2f}%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Starting Portfolio Value: 10000000.00
# 2020-04-25 - [매수 체결] 가격:7550.48, 수량:264.0000
# 2020-04-30 - [매수 체결] 가격:8797.67, 수량:234.0000
# 2020-05-03 - [매수 체결] 가격:8983.61, 수량:231.0000
# 2020-05-07 - [매수 체결] 가격:9261.90, 수량:228.0000
# 2020-05-08 - 주문 취소/마진/거부
# 2020-05-09 - 주문 취소/마진/거부
# 2020-05-10 - 주문 취소/마진/거부
# 2020-05-15 - 주문 취소/마진/거부
# 2020-05-18 - 주문 취소/마진/거부
# 2020-05-19 - 주문 취소/마진/거부
# 2020-05-20 - 주문 취소/마진/거부
# 2020-05-21 - 주문 취소/마진/거부
# 2020-05-29 - 주문 취소/마진/거부
# 2020-05-31 - 주문 취소/마진/거부
# 2020-06-02 - 주문 취소/마진/거부
# 2020-06-03 - 주문 취소/마진/거부
# 2020-06-04 - 주문 취소/마진/거부
# 2020-06-05 - 주문 취소/마진/거부
# 2020-06-06 - 주문 취소/마진/거부
# 2020-06-07 - 주문 취소/마진/거부
# 2020-06-08 - 주문 취소/마진/거부
# 2020-06-09 - 주문 취소/마진/거부
# 2020-06-10 - 주문 취소/마진/거부
# 2020-06-11 - 주문 취소/마진/거부
# 2020-06-13 - 주문 취소/마진/거부
# 2020-06-14 - 주문 취소/마진/거부
# 2020-06-17 - 주문 취소/마진/거부
# 2020-06-18 - 주문 취소/마진/거부
# 2020-06-20 - [매도 체결] 가격:9290.96, 수량:-957.0000
# 2020-06-20 - 거래 종료 - 손익: 652539.36, 수수료포함: 601148.29
# 2020-07-23 - [매수 체결] 가격:9527.14, 수량:222.0000
# 2020-07-28 - [매수 체결] 가격:11017.46, 수량:198.0000
# 2020-08-01 - [매수 체결] 가격:11322.57, 수량:195.0000
# 2020-08-02 - [매수 체결] 가격:11758.76, 수량:192.0000
# 2020-08-18 - 주문 취소/마진/거부
# 2020-08-19 - 주문 취소/마진/거부
# 2020-09-02 - 주문 취소/마진/거부
# 2020-09-04 - [매도 체결] 가격:10230.37, 수량:-807.0000
# 2020-09-04 - 거래 종료 - 손익: -506162.56, 수수료포함: -557216.48
# 2020-10-10 - [매수 체결] 가격:11059.14, 수량:181.0000
# 2020-10-22 - [매수 체결] 가격:12801.64, 수량:161.0000
# 2020-10-25 - [매수 체결] 가격:13108.06, 수량:159.0000
# 2020-10-28 - [매수 체결] 가격:13654.21, 수량:157.0000
# 2020-11-04 - 주문 취소/마진/거부
# 2020-11-05 - 주문 취소/마진/거부
# 2020-11-06 - 주문 취소/마진/거부
# 2020-11-07 - 주문 취소/마진/거부
# 2020-11-08 - 주문 취소/마진/거부
# 2020-11-09 - 주문 취소/마진/거부
# 2020-11-10 - 주문 취소/마진/거부
# 2020-11-11 - 주문 취소/마진/거부
# 2020-11-12 - 주문 취소/마진/거부
# 2020-11-13 - 주문 취소/마진/거부
# 2020-11-14 - 주문 취소/마진/거부
# 2020-11-15 - 주문 취소/마진/거부
# 2020-11-16 - 주문 취소/마진/거부
# 2020-11-17 - 주문 취소/마진/거부
# 2020-11-18 - 주문 취소/마진/거부
# 2020-11-19 - 주문 취소/마진/거부
# 2020-11-20 - 주문 취소/마진/거부
# 2020-11-21 - 주문 취소/마진/거부
# 2020-11-22 - 주문 취소/마진/거부
# 2020-11-23 - 주문 취소/마진/거부
# 2020-11-24 - 주문 취소/마진/거부
# 2020-11-25 - 주문 취소/마진/거부
# 2020-11-26 - 주문 취소/마진/거부
# 2020-11-27 - 주문 취소/마진/거부
# 2020-11-28 - 주문 취소/마진/거부
# 2020-11-29 - 주문 취소/마진/거부
# 2020-11-30 - 주문 취소/마진/거부
# 2020-12-01 - 주문 취소/마진/거부
# 2020-12-02 - 주문 취소/마진/거부
# 2020-12-03 - 주문 취소/마진/거부
# 2020-12-04 - 주문 취소/마진/거부
# 2020-12-05 - 주문 취소/마진/거부
# 2020-12-06 - 주문 취소/마진/거부
# 2020-12-07 - 주문 취소/마진/거부
# 2020-12-08 - 주문 취소/마진/거부
# 2020-12-09 - 주문 취소/마진/거부
# 2020-12-10 - 주문 취소/마진/거부
# 2020-12-11 - 주문 취소/마진/거부
# 2020-12-12 - 주문 취소/마진/거부
# 2020-12-13 - 주문 취소/마진/거부
# 2020-12-14 - 주문 취소/마진/거부
# 2020-12-15 - 주문 취소/마진/거부
# 2020-12-16 - 주문 취소/마진/거부
# 2020-12-17 - 주문 취소/마진/거부
# 2020-12-18 - 주문 취소/마진/거부
# 2020-12-19 - 주문 취소/마진/거부
# 2020-12-20 - 주문 취소/마진/거부
# 2020-12-21 - 주문 취소/마진/거부
# 2020-12-22 - 주문 취소/마진/거부
# 2020-12-23 - 주문 취소/마진/거부
# 2020-12-24 - 주문 취소/마진/거부
# 2020-12-25 - 주문 취소/마진/거부
# 2020-12-26 - 주문 취소/마진/거부
# 2020-12-27 - 주문 취소/마진/거부
# 2020-12-28 - 주문 취소/마진/거부
# 2020-12-29 - 주문 취소/마진/거부
# 2020-12-30 - 주문 취소/마진/거부
# 2020-12-31 - 주문 취소/마진/거부
# 2021-01-01 - 주문 취소/마진/거부
# 2021-01-02 - 주문 취소/마진/거부
# 2021-01-03 - 주문 취소/마진/거부
# 2021-01-04 - 주문 취소/마진/거부
# 2021-01-05 - 주문 취소/마진/거부
# 2021-01-06 - 주문 취소/마진/거부
# 2021-01-07 - 주문 취소/마진/거부
# 2021-01-08 - 주문 취소/마진/거부
# 2021-01-09 - 주문 취소/마진/거부
# 2021-01-10 - 주문 취소/마진/거부
# 2021-01-11 - 주문 취소/마진/거부
# 2021-01-12 - 주문 취소/마진/거부
# 2021-01-13 - 주문 취소/마진/거부
# 2021-01-14 - 주문 취소/마진/거부
# 2021-01-15 - 주문 취소/마진/거부
# 2021-01-16 - 주문 취소/마진/거부
# 2021-01-17 - 주문 취소/마진/거부
# 2021-01-18 - 주문 취소/마진/거부
# 2021-01-19 - 주문 취소/마진/거부
# 2021-01-20 - 주문 취소/마진/거부
# 2021-01-21 - 주문 취소/마진/거부
# 2021-01-22 - 주문 취소/마진/거부
# 2021-01-23 - 주문 취소/마진/거부
# 2021-01-24 - 주문 취소/마진/거부
# 2021-01-25 - 주문 취소/마진/거부
# 2021-01-26 - 주문 취소/마진/거부
# 2021-01-27 - 주문 취소/마진/거부
# 2021-01-28 - 주문 취소/마진/거부
# 2021-01-29 - 주문 취소/마진/거부
# 2021-01-30 - 주문 취소/마진/거부
# 2021-01-31 - 주문 취소/마진/거부
# 2021-02-01 - 주문 취소/마진/거부
# 2021-02-02 - 주문 취소/마진/거부
# 2021-02-03 - 주문 취소/마진/거부
# 2021-02-04 - 주문 취소/마진/거부
# 2021-02-05 - 주문 취소/마진/거부
# 2021-02-06 - 주문 취소/마진/거부
# 2021-02-07 - 주문 취소/마진/거부
# 2021-02-08 - 주문 취소/마진/거부
# 2021-02-09 - 주문 취소/마진/거부
# 2021-02-10 - 주문 취소/마진/거부
# 2021-02-11 - 주문 취소/마진/거부
# 2021-02-12 - 주문 취소/마진/거부
# 2021-02-13 - 주문 취소/마진/거부
# 2021-02-14 - 주문 취소/마진/거부
# 2021-02-15 - 주문 취소/마진/거부
# 2021-02-16 - 주문 취소/마진/거부
# 2021-02-17 - 주문 취소/마진/거부
# 2021-02-18 - 주문 취소/마진/거부
# 2021-02-19 - 주문 취소/마진/거부
# 2021-02-20 - 주문 취소/마진/거부
# 2021-02-21 - 주문 취소/마진/거부
# 2021-02-22 - 주문 취소/마진/거부
# 2021-02-23 - 주문 취소/마진/거부
# 2021-02-24 - 주문 취소/마진/거부
# 2021-02-25 - 주문 취소/마진/거부
# 2021-02-26 - 주문 취소/마진/거부
# 2021-02-27 - 주문 취소/마진/거부
# 2021-02-28 - 주문 취소/마진/거부
# 2021-03-01 - 주문 취소/마진/거부
# 2021-03-02 - 주문 취소/마진/거부
# 2021-03-03 - 주문 취소/마진/거부
# 2021-03-04 - 주문 취소/마진/거부
# 2021-03-05 - 주문 취소/마진/거부
# 2021-03-06 - 주문 취소/마진/거부
# 2021-03-07 - 주문 취소/마진/거부
# 2021-03-08 - 주문 취소/마진/거부
# 2021-03-09 - 주문 취소/마진/거부
# 2021-03-10 - 주문 취소/마진/거부
# 2021-03-11 - 주문 취소/마진/거부
# 2021-03-12 - 주문 취소/마진/거부
# 2021-03-13 - 주문 취소/마진/거부
# 2021-03-14 - 주문 취소/마진/거부
# 2021-03-15 - 주문 취소/마진/거부
# 2021-03-16 - 주문 취소/마진/거부
# 2021-03-17 - 주문 취소/마진/거부
# 2021-03-18 - 주문 취소/마진/거부
# 2021-03-19 - 주문 취소/마진/거부
# 2021-03-20 - 주문 취소/마진/거부
# 2021-03-21 - 주문 취소/마진/거부
# 2021-03-22 - 주문 취소/마진/거부
# 2021-03-23 - 주문 취소/마진/거부
# 2021-03-24 - 주문 취소/마진/거부
# 2021-03-25 - 주문 취소/마진/거부
# 2021-03-26 - 주문 취소/마진/거부
# 2021-03-27 - 주문 취소/마진/거부
# 2021-03-28 - 주문 취소/마진/거부
# 2021-03-29 - 주문 취소/마진/거부
# 2021-03-30 - 주문 취소/마진/거부
# 2021-03-31 - 주문 취소/마진/거부
# 2021-04-01 - 주문 취소/마진/거부
# 2021-04-02 - 주문 취소/마진/거부
# 2021-04-03 - 주문 취소/마진/거부
# 2021-04-04 - 주문 취소/마진/거부
# 2021-04-05 - 주문 취소/마진/거부
# 2021-04-06 - 주문 취소/마진/거부
# 2021-04-07 - 주문 취소/마진/거부
# 2021-04-08 - 주문 취소/마진/거부
# 2021-04-09 - 주문 취소/마진/거부
# 2021-04-10 - 주문 취소/마진/거부
# 2021-04-11 - 주문 취소/마진/거부
# 2021-04-12 - 주문 취소/마진/거부
# 2021-04-13 - 주문 취소/마진/거부
# 2021-04-14 - 주문 취소/마진/거부
# 2021-04-15 - 주문 취소/마진/거부
# 2021-04-16 - 주문 취소/마진/거부
# 2021-04-17 - 주문 취소/마진/거부
# 2021-04-18 - 주문 취소/마진/거부
# 2021-04-19 - 주문 취소/마진/거부
# 2021-04-19 - [매도 체결] 가격:56191.59, 수량:-658.0000
# 2021-04-19 - 거래 종료 - 손익: 28683401.56, 수수료포함: 28547607.39
# 2021-07-27 - [매수 체결] 가격:37276.04, 수량:206.0000
# 2021-07-31 - [매수 체결] 가격:42196.30, 수량:187.0000
# 2021-08-08 - [매수 체결] 가격:44574.44, 수량:181.0000
# 2021-08-10 - [매수 체결] 가격:46280.85, 수량:178.0000
# 2021-08-14 - 주문 취소/마진/거부
# 2021-08-15 - 주문 취소/마진/거부
# 2021-08-16 - 주문 취소/마진/거부
# 2021-08-20 - 주문 취소/마진/거부
# 2021-08-21 - 주문 취소/마진/거부
# 2021-08-22 - 주문 취소/마진/거부
# 2021-08-23 - 주문 취소/마진/거부
# 2021-08-24 - 주문 취소/마진/거부
# 2021-08-25 - 주문 취소/마진/거부
# 2021-08-26 - 주문 취소/마진/거부
# 2021-08-27 - 주문 취소/마진/거부
# 2021-08-28 - 주문 취소/마진/거부
# 2021-08-29 - 주문 취소/마진/거부
# 2021-08-30 - 주문 취소/마진/거부
# 2021-08-31 - 주문 취소/마진/거부
# 2021-09-01 - 주문 취소/마진/거부
# 2021-09-02 - 주문 취소/마진/거부
# 2021-09-03 - 주문 취소/마진/거부
# 2021-09-04 - 주문 취소/마진/거부
# 2021-09-05 - 주문 취소/마진/거부
# 2021-09-06 - 주문 취소/마진/거부
# 2021-09-07 - 주문 취소/마진/거부
# 2021-09-08 - 주문 취소/마진/거부
# 2021-09-11 - [매도 체결] 가격:44869.84, 수량:-752.0000
# 2021-09-11 - 거래 종료 - 손익: 1866583.27, 수수료포함: 1669730.31
# 2021-10-06 - [매수 체결] 가격:51486.66, 수량:156.0000
# 2021-10-12 - [매수 체결] 가격:57526.83, 수량:143.0000
# 2021-10-16 - [매수 체결] 가격:61609.53, 수량:137.0000
# 2021-10-20 - [매수 체결] 가격:64284.59, 수량:135.0000
# 2021-10-21 - 주문 취소/마진/거부
# 2021-11-09 - 주문 취소/마진/거부
# 2021-11-10 - 주문 취소/마진/거부
# 2021-11-11 - 주문 취소/마진/거부
# 2021-11-12 - 주문 취소/마진/거부
# 2021-11-14 - 주문 취소/마진/거부
# 2021-11-15 - 주문 취소/마진/거부
# 2021-11-19 - [매도 체결] 가격:56896.13, 수량:-571.0000
# 2021-11-19 - 거래 종료 - 손익: -889491.32, 수수료포함: -1087085.93
# 2022-02-08 - [매수 체결] 가격:43854.65, 수량:178.0000
# 2022-02-12 - [매도 체결] 가격:42412.30, 수량:-178.0000
# 2022-02-12 - 거래 종료 - 손익: -256738.58, 수수료포함: -302805.13
# 2022-03-25 - [매수 체결] 가격:43964.55, 수량:176.0000
# 2022-04-12 - [매도 체결] 가격:39533.71, 수량:-176.0000
# 2022-04-12 - 거래 종료 - 손익: -779826.44, 수수료포함: -823913.52
# 2022-05-31 - [매수 체결] 가격:31723.87, 수량:239.0000
# 2022-06-01 - [매도 체결] 가격:31792.55, 수량:-239.0000
# 2022-06-01 - 거래 종료 - 손익: 16416.78, 수수료포함: -29124.49
# 2022-07-19 - [매수 체결] 가격:22467.85, 수량:338.0000
# 2022-07-24 - [매도 체결] 가격:22465.51, 수량:-338.0000
# 2022-07-24 - 거래 종료 - 손익: -790.87, 수수료포함: -46353.29
# 2022-09-13 - [매수 체결] 가격:22371.48, 수량:339.0000
# 2022-09-14 - [매도 체결] 가격:20184.55, 수량:-339.0000
# 2022-09-14 - 거래 종료 - 손익: -741367.84, 수수료포함: -784647.33
# 2022-10-05 - [매수 체결] 가격:20335.90, 수량:365.0000
# 2022-10-06 - [매도 체결] 가격:20161.04, 수량:-365.0000
# 2022-10-06 - 거래 종료 - 손익: -63824.38, 수수료포함: -108168.53
# 2022-10-26 - [매수 체결] 가격:20092.24, 수량:369.0000
# 2022-11-09 - [매도 체결] 가격:18543.76, 수량:-369.0000
# 2022-11-09 - 거래 종료 - 손익: -571387.13, 수수료포함: -614157.18
# 2022-12-01 - [매수 체결] 가격:17168.00, 수량:424.0000
# 2022-12-02 - [매도 체결] 가격:16968.68, 수량:-424.0000
# 2022-12-02 - 거래 종료 - 손익: -84510.98, 수수료포함: -127932.85
# 2022-12-14 - [매수 체결] 가격:17782.07, 수량:408.0000
# 2022-12-15 - [매도 체결] 가격:17813.64, 수량:-408.0000
# 2022-12-15 - 거래 종료 - 손익: 12883.88, 수수료포함: -30685.28
# 2023-01-09 - [매수 체결] 가격:17093.99, 수량:424.0000
# 2023-01-13 - [매수 체결] 가격:18868.91, 수량:392.0000
# 2023-01-14 - [매수 체결] 가격:19910.54, 수량:380.0000
# 2023-01-15 - [매수 체결] 가격:20977.48, 수량:372.0000
# 2023-01-17 - 주문 취소/마진/거부
# 2023-01-18 - 주문 취소/마진/거부
# 2023-01-20 - 주문 취소/마진/거부
# 2023-01-21 - 주문 취소/마진/거부
# 2023-01-22 - 주문 취소/마진/거부
# 2023-01-23 - 주문 취소/마진/거부
# 2023-01-24 - 주문 취소/마진/거부
# 2023-01-25 - 주문 취소/마진/거부
# 2023-01-26 - 주문 취소/마진/거부
# 2023-01-27 - 주문 취소/마진/거부
# 2023-01-28 - 주문 취소/마진/거부
# 2023-01-29 - 주문 취소/마진/거부
# 2023-01-30 - 주문 취소/마진/거부
# 2023-01-31 - 주문 취소/마진/거부
# 2023-02-01 - 주문 취소/마진/거부
# 2023-02-02 - 주문 취소/마진/거부
# 2023-02-03 - 주문 취소/마진/거부
# 2023-02-04 - 주문 취소/마진/거부
# 2023-02-05 - 주문 취소/마진/거부
# 2023-02-06 - 주문 취소/마진/거부
# 2023-02-07 - 주문 취소/마진/거부
# 2023-02-08 - 주문 취소/마진/거부
# 2023-02-09 - 주문 취소/마진/거부
# 2023-02-10 - 주문 취소/마진/거부
# 2023-02-11 - 주문 취소/마진/거부
# 2023-02-12 - 주문 취소/마진/거부
# 2023-02-13 - 주문 취소/마진/거부
# 2023-02-14 - 주문 취소/마진/거부
# 2023-02-15 - 주문 취소/마진/거부
# 2023-02-16 - 주문 취소/마진/거부
# 2023-02-17 - 주문 취소/마진/거부
# 2023-02-18 - 주문 취소/마진/거부
# 2023-02-19 - 주문 취소/마진/거부
# 2023-02-20 - 주문 취소/마진/거부
# 2023-02-21 - 주문 취소/마진/거부
# 2023-02-22 - 주문 취소/마진/거부
# 2023-02-23 - 주문 취소/마진/거부
# 2023-02-24 - 주문 취소/마진/거부
# 2023-02-25 - 주문 취소/마진/거부
# 2023-02-26 - 주문 취소/마진/거부
# 2023-02-27 - 주문 취소/마진/거부
# 2023-02-28 - 주문 취소/마진/거부
# 2023-03-01 - 주문 취소/마진/거부
# 2023-03-02 - 주문 취소/마진/거부
# 2023-03-03 - 주문 취소/마진/거부
# 2023-03-04 - 주문 취소/마진/거부
# 2023-03-04 - [매도 체결] 가격:22362.92, 수량:-1568.0000
# 2023-03-04 - 거래 종료 - 손익: 5050972.34, 수수료포함: 4855734.87
# 2023-03-18 - [매수 체결] 가격:27448.12, 수량:300.0000
# 2023-04-12 - [매수 체결] 가격:30231.58, 수량:277.0000
# 2023-05-02 - [매도 체결] 가격:28087.18, 수량:-577.0000
# 2023-05-02 - 거래 종료 - 손익: -402282.95, 수수료포함: -500727.60
# 2023-05-29 - [매수 체결] 가격:28075.59, 수량:289.0000
# 2023-05-30 - [매도 체결] 가격:27745.12, 수량:-289.0000
# 2023-05-30 - 거래 종료 - 손익: -95505.47, 수수료포함: -143902.03
# 2023-06-21 - [매수 체결] 가격:28311.31, 수량:286.0000
# 2023-07-04 - [매수 체결] 가격:31156.87, 수량:265.0000
# 2023-07-31 - [매도 체결] 가격:29278.31, 수량:-551.0000
# 2023-07-31 - 거래 종료 - 손익: -221252.84, 수수료포함: -318710.71
# 2023-09-20 - [매수 체결] 가격:27210.23, 수량:295.0000
# 2023-09-21 - [매도 체결] 가격:27129.84, 수량:-295.0000
# 2023-09-21 - 거래 종료 - 손익: -23714.66, 수수료포함: -71805.62
# 2023-10-02 - [매수 체결] 가격:27976.80, 수량:286.0000
# 2023-10-24 - [매수 체결] 가격:33077.30, 수량:251.0000
# 2023-10-25 - [매수 체결] 가격:33916.04, 수량:247.0000
# 2023-11-01 - [매수 체결] 가격:34657.27, 수량:245.0000
# 2023-11-09 - 주문 취소/마진/거부
# 2023-11-10 - 주문 취소/마진/거부
# 2023-11-11 - 주문 취소/마진/거부
# 2023-11-12 - 주문 취소/마진/거부
# 2023-11-13 - 주문 취소/마진/거부
# 2023-11-14 - 주문 취소/마진/거부
# 2023-11-15 - 주문 취소/마진/거부
# 2023-11-16 - 주문 취소/마진/거부
# 2023-11-17 - 주문 취소/마진/거부
# 2023-11-18 - 주문 취소/마진/거부
# 2023-11-19 - 주문 취소/마진/거부
# 2023-11-20 - 주문 취소/마진/거부
# 2023-11-21 - 주문 취소/마진/거부
# 2023-11-22 - 주문 취소/마진/거부
# 2023-11-23 - 주문 취소/마진/거부
# 2023-11-24 - 주문 취소/마진/거부
# 2023-11-25 - 주문 취소/마진/거부
# 2023-11-26 - 주문 취소/마진/거부
# 2023-11-27 - 주문 취소/마진/거부
# 2023-11-28 - 주문 취소/마진/거부
# 2023-11-29 - 주문 취소/마진/거부
# 2023-11-30 - 주문 취소/마진/거부
# 2023-12-01 - 주문 취소/마진/거부
# 2023-12-02 - 주문 취소/마진/거부
# 2023-12-03 - 주문 취소/마진/거부
# 2023-12-04 - 주문 취소/마진/거부
# 2023-12-05 - 주문 취소/마진/거부
# 2023-12-06 - 주문 취소/마진/거부
# 2023-12-07 - 주문 취소/마진/거부
# 2023-12-08 - 주문 취소/마진/거부
# 2023-12-09 - 주문 취소/마진/거부
# 2023-12-10 - 주문 취소/마진/거부
# 2023-12-11 - 주문 취소/마진/거부
# 2023-12-12 - 주문 취소/마진/거부
# 2023-12-13 - 주문 취소/마진/거부
# 2023-12-14 - 주문 취소/마진/거부
# 2023-12-15 - 주문 취소/마진/거부
# 2023-12-16 - 주문 취소/마진/거부
# 2023-12-17 - 주문 취소/마진/거부
# 2023-12-18 - 주문 취소/마진/거부
# 2023-12-19 - 주문 취소/마진/거부
# 2023-12-20 - 주문 취소/마진/거부
# 2023-12-21 - 주문 취소/마진/거부
# 2023-12-22 - 주문 취소/마진/거부
# 2023-12-23 - 주문 취소/마진/거부
# 2023-12-24 - 주문 취소/마진/거부
# 2023-12-25 - 주문 취소/마진/거부
# 2023-12-26 - 주문 취소/마진/거부
# 2023-12-27 - 주문 취소/마진/거부
# 2023-12-28 - 주문 취소/마진/거부
# 2023-12-29 - 주문 취소/마진/거부
# 2023-12-30 - 주문 취소/마진/거부
# 2023-12-31 - 주문 취소/마진/거부
# 2024-01-01 - 주문 취소/마진/거부
# 2024-01-02 - 주문 취소/마진/거부
# 2024-01-03 - 주문 취소/마진/거부
# 2024-01-04 - 주문 취소/마진/거부
# 2024-01-05 - 주문 취소/마진/거부
# 2024-01-06 - 주문 취소/마진/거부
# 2024-01-07 - 주문 취소/마진/거부
# 2024-01-08 - 주문 취소/마진/거부
# 2024-01-09 - 주문 취소/마진/거부
# 2024-01-10 - 주문 취소/마진/거부
# 2024-01-11 - 주문 취소/마진/거부
# 2024-01-12 - 주문 취소/마진/거부
# 2024-01-13 - 주문 취소/마진/거부
# 2024-01-14 - 주문 취소/마진/거부
# 2024-01-15 - 주문 취소/마진/거부
# 2024-01-15 - [매도 체결] 가격:41715.07, 수량:-1029.0000
# 2024-01-15 - 거래 종료 - 손익: 9752740.79, 수수료포함: 9524450.19
# 2024-02-09 - [매수 체결] 가격:45297.38, 수량:219.0000
# 2024-02-13 - [매수 체결] 가격:49941.36, 수량:202.0000
# 2024-02-21 - [매수 체결] 가격:52273.54, 수량:197.0000
# 2024-02-27 - [매수 체결] 가격:54519.36, 수량:194.0000
# 2024-02-28 - 주문 취소/마진/거부
# 2024-02-29 - 주문 취소/마진/거부
# 2024-03-01 - 주문 취소/마진/거부
# 2024-03-02 - 주문 취소/마진/거부
# 2024-03-03 - 주문 취소/마진/거부
# 2024-03-04 - 주문 취소/마진/거부
# 2024-03-05 - 주문 취소/마진/거부
# 2024-03-06 - 주문 취소/마진/거부
# 2024-03-07 - 주문 취소/마진/거부
# 2024-03-08 - 주문 취소/마진/거부
# 2024-03-09 - 주문 취소/마진/거부
# 2024-03-10 - 주문 취소/마진/거부
# 2024-03-11 - 주문 취소/마진/거부
# 2024-03-12 - 주문 취소/마진/거부
# 2024-03-13 - 주문 취소/마진/거부
# 2024-03-14 - 주문 취소/마진/거부
# 2024-03-15 - 주문 취소/마진/거부
# 2024-03-16 - 주문 취소/마진/거부
# 2024-03-17 - 주문 취소/마진/거부
# 2024-03-18 - 주문 취소/마진/거부
# 2024-03-19 - 주문 취소/마진/거부
# 2024-03-20 - 주문 취소/마진/거부
# 2024-03-21 - 주문 취소/마진/거부
# 2024-03-22 - 주문 취소/마진/거부
# 2024-03-23 - 주문 취소/마진/거부
# 2024-03-24 - 주문 취소/마진/거부
# 2024-03-25 - 주문 취소/마진/거부
# 2024-03-26 - 주문 취소/마진/거부
# 2024-03-27 - 주문 취소/마진/거부
# 2024-03-28 - 주문 취소/마진/거부
# 2024-03-29 - 주문 취소/마진/거부
# 2024-03-30 - 주문 취소/마진/거부
# 2024-03-31 - 주문 취소/마진/거부
# 2024-04-01 - 주문 취소/마진/거부
# 2024-04-02 - 주문 취소/마진/거부
# 2024-04-03 - 주문 취소/마진/거부
# 2024-04-04 - 주문 취소/마진/거부
# 2024-04-05 - 주문 취소/마진/거부
# 2024-04-06 - 주문 취소/마진/거부
# 2024-04-07 - 주문 취소/마진/거부
# 2024-04-08 - 주문 취소/마진/거부
# 2024-04-09 - 주문 취소/마진/거부
# 2024-04-10 - 주문 취소/마진/거부
# 2024-04-11 - 주문 취소/마진/거부
# 2024-04-12 - 주문 취소/마진/거부
# 2024-04-13 - 주문 취소/마진/거부
# 2024-04-14 - 주문 취소/마진/거부
# 2024-04-14 - [매도 체결] 가격:63836.23, 수량:-812.0000
# 2024-04-14 - 거래 종료 - 손익: 10952094.81, 수수료포함: 10673940.98
# 2024-05-16 - [매수 체결] 가격:66256.11, 수량:182.0000
# 2024-06-15 - [매도 체결] 가격:66006.74, 수량:-182.0000
# 2024-06-15 - 거래 종료 - 손익: -45384.83, 수수료포함: -117600.35
# 2024-07-16 - [매수 체결] 가격:64784.42, 수량:185.0000
# 2024-08-03 - [매도 체결] 가격:61414.81, 수량:-185.0000
# 2024-08-03 - 거래 종료 - 손익: -623377.73, 수수료포함: -693418.31
# 2024-08-24 - [매수 체결] 가격:64103.87, 수량:185.0000
# 2024-08-28 - [매도 체결] 가격:59507.93, 수량:-185.0000
# 2024-08-28 - 거래 종료 - 손익: -850249.88, 수수료포함: -918854.43
# 2024-09-20 - [매수 체결] 가격:62941.43, 수량:186.0000
# 2024-10-10 - [매도 체결] 가격:60581.93, 수량:-186.0000
# 2024-10-10 - 거래 종료 - 손익: -438866.27, 수수료포함: -507792.31
# 2024-10-30 - [매수 체결] 가격:72715.37, 수량:159.0000
# 2024-11-11 - [매수 체결] 가격:80471.41, 수량:147.0000
# 2024-11-12 - [매수 체결] 가격:88705.56, 수량:139.0000
# 2024-11-14 - [매수 체결] 가격:90574.88, 수량:138.0000
# 2024-11-16 - 주문 취소/마진/거부
# 2024-11-20 - 주문 취소/마진/거부
# 2024-11-21 - 주문 취소/마진/거부
# 2024-11-22 - 주문 취소/마진/거부
# 2024-11-23 - 주문 취소/마진/거부
# 2024-11-24 - 주문 취소/마진/거부
# 2024-11-25 - 주문 취소/마진/거부
# 2024-11-26 - 주문 취소/마진/거부
# 2024-11-27 - 주문 취소/마진/거부
# 2024-11-28 - 주문 취소/마진/거부
# 2024-11-29 - 주문 취소/마진/거부
# 2024-11-30 - 주문 취소/마진/거부
# Final Portfolio Value: 65952399.93
# 수익률: 659.52%

# %% [markdown]
# 뭔가 추가적으로 설정하는 것보다 가장 단순한게 성능이 가장 잘 나왔다
